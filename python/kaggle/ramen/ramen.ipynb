# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline
mpl.rcParams["axis_unicode_minus"] = False
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     676             try:
# --> 677                 cval = self.validate[key](val)
#     678             except ValueError as ve:
#
# KeyError: 'axis_unicode_minus'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-47a06ba5164e> in <module>
#       5
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 7 mpl.rcParams["axis_unicode_minus"] = False
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     680             dict.__setitem__(self, key, cval)
#     681         except KeyError as err:
# --> 682             raise KeyError(
# ...
